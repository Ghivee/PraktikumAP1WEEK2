# %%
# Bilangan Bulat
11231
# Out:
# 11231

# %%
# Float
2.14
# Out:
# 2.14

# %%
type(11231)
# Out:
# int

# %%
type(2.14)
# Out:
# float

# %%
type("Hello Guys")
# Out:
# str

# %%
type(12.0)
# Out:
# float

# %%
type(-12)
# Out:
# int

# %%
type(321.321)
# Out:
# float

# %%
type(1.0) # walaupun 1.0 sebenarnya bulat tetapi apabila angka dibelakang titik tetap ditulis maka system tetap menganggap itu float
# Out:
# float

# %%
int(12.33) # ini adalah perintah untuk mengubah float menjadi int
# Out:
# 12

# %%
float(14) # ini adalah perintah untuk mengubah int menjadi float
# Out:
# 14.0

# %%
float(12.99)
# Out:
# 12.99

# %%
int(12)
# Out:
# 12

# %%
str(1)
# Out:
# '1'

# %%
str(22.2)
# Out:
# '22.2'

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
float(True)
# Out:
# 1.0

# %%
type(90-89.9) # float atau int juga bisa kita dapatkan menggunakan penjumlahan
# Out:
# float

# %%
type(90-89)
# Out:
# int

# %%
10*10 # kita bisa menggunakan perkalian dengan tanda (*)
# Out:
# 100

# %%
15/5 # lalu pembagian menggunakan tanda (/)
# Out:
# 3.0

# %%
int(12/11) # apabila hasil perkalian atau pembagian merupakan bilangan float, kita dapat membuatnya otomatis int dengan perintah int
# Out:
# 1

# %%
25//10 # tanda (/) ganda juga berfungsi sama seperti perintah int yaitu untuk membuat hasil menjadi bilangan bulat atau int terdekat
# Out:
# 2

# %%
160/9999
# Out:
# 0.016001600160016

# %%
(50*10) + 60
# Out:
# 560

# %%
x = 30 + 1
x
# Out:
# 31

# %%
x = 30+21
y = 40+9
x*y
# Out:
# 2499

# %%
total_min = 10 + 10 + 10
total_min
# Out:
# 30

# %%
float(total_min)
# Out:
# 30.0

# %%
panjang = 20.5
lebar = 25
tinggi = 10

keliling =2*(panjang+lebar)
luas = panjang*lebar
volume = panjang*lebar*tinggi

print ('Panjang =',panjang)
print ('Lebar =',lebar)
print ('Tinggi =',tinggi)
print ('Keliling =',keliling)
print ('Volume =',volume)
# Out:
# Panjang = 20.5
# Lebar = 25
# Tinggi = 10
# Keliling = 91.0
# Volume = 5125.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
rata_rata_nilai_shafira = (85+75)/2
print ('1. Rata-rata nilai Shafira pada kedua mata kuliah                                 =',rata_rata_nilai_shafira)

jumlah_nilai_hanif_andi = 75+90+70+75
print ('2. Jumlah nilai Hanif dan Andi untuk semua mata kuliah                            =',jumlah_nilai_hanif_andi)

nilai_rata_rata_kalkulus_Widya_Dhanar_Hikma_nedia = (85+85+80+95)/4
nilai_rata_rata_statistika_Widya_Dhanar_Hikma_nedia = (85+85+75+80)/4
print ('3. Nilai rata-rata mata kuliah Kalkulus 1 Widya, Dhanar, Hikma, dan Nedia         =',nilai_rata_rata_kalkulus_Widya_Dhanar_Hikma_nedia)
print ('   Nilai rata-rata mata kuliah Metode Statistika Widya, Dhanar, Hikma, dan Nedia  =',nilai_rata_rata_statistika_Widya_Dhanar_Hikma_nedia)

nilai_rata_rata_kalkulus_all = (85+80+75+95+85+75+70+85+80)/9
print ('4. Rata-rata nilai mata kuliah Kalkulus 1 untuk semua mahasiswa                   =',nilai_rata_rata_kalkulus_all)

nilai_rata_rata_statistika_all = (75+90+80+80+85+90+75+85+75)/9
print ('5. Rata-rata nilai mata kuliah Metode Statistika untuk mahasiswa                  =',nilai_rata_rata_statistika_all)
# Out:
# 1. Rata-rata nilai Shafira pada kedua mata kuliah                                 = 80.0
# 2. Jumlah nilai Hanif dan Andi untuk semua mata kuliah                            = 310
# 3. Nilai rata-rata mata kuliah Kalkulus 1 Widya, Dhanar, Hikma, dan Nedia         = 86.25
#    Nilai rata-rata mata kuliah Metode Statistika Widya, Dhanar, Hikma, dan Nedia  = 81.25
# 4. Rata-rata nilai mata kuliah Kalkulus 1 untuk semua mahasiswa                   = 81.11111111111111
# 5. Rata-rata nilai mata kuliah Metode Statistika untuk mahasiswa                  = 81.66666666666667

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
bekerja_sehari = 8 #jam
sejam = 30.000 #ribu rupiah
agustus_tidak_masuk_3_hari = (8*28)*30.000
print('1. Gaji pada bulan Agustus jika Dwi tidak masuk kerja selama 3 hari =',agustus_tidak_masuk_3_hari)

total_gaji_sebulan = (8*31)*30.000
tunjangan_agustus = total_gaji_sebulan*(10/100)
print('2. Jumlah tunjangan yang diterima Dwi pada bulan Agustus            =',tunjangan_agustus)

upah_gaji_lembur = 10.000 #per jam
print('3. Gaji total yang diterima oleh Dwi pada bulan Agustus             =',total_gaji_sebulan + (upah_gaji_lembur*5))
# Out:
# 1. Gaji pada bulan Agustus jika Dwi tidak masuk kerja selama 3 hari = 6720.0
# 2. Jumlah tunjangan yang diterima Dwi pada bulan Agustus            = 744.0
# 3. Gaji total yang diterima oleh Dwi pada bulan Agustus             = 7490.0
